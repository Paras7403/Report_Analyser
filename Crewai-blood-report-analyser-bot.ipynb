# %%
import os
from crewai import Agent, Task, Crew
from PyPDF2 import PdfReader
from crewai_tools import SerperDevTool, WebsiteSearchTool

# Set up API keys
os.environ["SERPER_API_KEY"] = ""
os.environ["OPENAI_API_KEY"] = ""

pdf = 'C:/Users/asus/Desktop/crewai-blood-report-analyser-bot/report.pdf'
pages_to_extract = [1, 3]

raw_text = ''
with open(pdf, 'rb') as file:
    reader = PdfReader(file)
    for page_num in pages_to_extract:
        page = reader.pages[page_num - 1] 
        content = page.extract_text()
        if content:
            raw_text += content

print(raw_text)

# Define tools
search_tool = SerperDevTool()
web_search_tool = WebsiteSearchTool()

blood_test_analyst = Agent(
    role='Blood Test Analyst',
    goal='Analyze the blood test report and summarize the findings.',
    backstory='A medical expert specializing in blood test analysis.',
    verbose=True,
    allow_delegation=False,
    model='gpt-4o-mini'  # Set a valid model name here
)

article_researcher = Agent(
    role='Article Researcher',
    goal='Search for health articles based on blood test results.',
    backstory='An expert researcher proficient in finding health-related articles.',
    tools=[search_tool, web_search_tool],
    verbose=True,
    allow_delegation=False,
    model='gpt-4o'  # Set a valid model name here
)

health_advisor = Agent(
    role='Health Advisor',
    goal='Provide health recommendations based on the articles found.',
    backstory='A health advisor with extensive knowledge in providing health advice.',
    verbose=True,
    allow_delegation=False,
    model='gpt-4o'  # Set a valid model name here
)


# Define Tasks
analyze_blood_test_task = Task(
    description= f'You have to analyze the blood test report from "{raw_text}" blood report',
    expected_output='A summary of the blood test results.',
    agent=blood_test_analyst,
)

find_articles_task = Task(
    description='Search for health articles based on the blood test analysis.',
    expected_output='A list of relevant health articles with links.',
    agent=article_researcher,
    context=[analyze_blood_test_task]
)

provide_recommendations_task = Task(
    description='Provide health recommendations based on the articles found.',
    expected_output='Health recommendations with links to the articles.',
    agent=health_advisor,
    context=[find_articles_task]
)

# Create a Crew
crew = Crew(
    agents=[blood_test_analyst, article_researcher, health_advisor],
    tasks=[analyze_blood_test_task, find_articles_task, provide_recommendations_task],
    verbose=False
)

# Execute Tasks
crew.kickoff()
# Out:
# Report Status    Male30 Years:
# :
# :
# :Age
# Gender
# Reported
# P14/5/2023  11:03:00AMU439854467   DUMMY:
# :
# :
# :
# :Name
# Lab No.
# Ref By
# Collected
# A/c Status 16/5/2023  1:36:25PM
# Final
# Collected at            : Processed at             : LPL-ROHINI (NATIONAL REFERENCE LAB)
# National Reference laboratory, Block E, Sector
# 18, ROHINI
# DELHI 110085LPL-NATIONAL REFERENCE LAB
# National Reference laboratory, Block E,
# Sector 18, Rohini, New Delhi -110085
# Test Report
# Test Name Results Units Bio. Ref. Interval
# SwasthFit Super 4
# COMPLETE BLOOD COUNT;CBC
# Hemoglobin
# (Photometry) 13.00 - 17.00 g/dL 15.00
# Packed Cell Volume (PCV)
# (Calculated) 40.00 - 50.00 % 45.00
# RBC Count
# (Electrical Impedence) 4.50 - 5.50 mill/mm3 4.50
# MCV
# (Electrical Impedence) 83.00 - 101.00 fL 90.00
# MCH
# (Calculated) 27.00 - 32.00 pg 32.00
# MCHC
# (Calculated) 31.50 - 34.50 g/dL 33.00
# Red Cell Distribution Width (RDW)
# (Electrical Impedence) 11.60 - 14.00 % 14.00
# Total Leukocyte Count  (TLC)
# (Electrical Impedence) 4.00 - 10.00 thou/mm3 8.00
# Differential Leucocyte Count (DLC)
# (VCS Technology)
#  40.00 - 80.00 Segmented Neutrophils % 60.00
#  20.00 - 40.00 Lymphocytes % 30.00
#  2.00 - 10.00 Monocytes % 5.00
#  1.00 - 6.00 Eosinophils % 5.00
#  <2.00 Basophils % 0.00
# Absolute Leucocyte Count
# (Calculated)
#  2.00 - 7.00 Neutrophils thou/mm3 4.80
#  1.00 - 3.00 Lymphocytes thou/mm3 2.40
#  0.20 - 1.00 Monocytes thou/mm3 0.40
#  0.02 - 0.50 Eosinophils thou/mm3 0.40
#  0.02 - 0.10 Basophils thou/mm3 0.00
# Platelet Count
# (Electrical impedence) 150.00 - 410.00 thou/mm3 200
# Mean Platelet Volume
# (Electrical Impedence) 6.5 - 12.0 fL 10.0
# *439854467*
# .
# Page 1 of 10
# Report Status    Male30 Years:
# :
# :
# :Age
# Gender
# Reported
# P14/5/2023  11:03:00AMU439854467   DUMMY:
# :
# :
# :
# :Name
# Lab No.
# Ref By
# Collected
# A/c Status 16/5/2023  1:36:25PM
# Final
# Collected at            : Processed at             : LPL-ROHINI (NATIONAL REFERENCE LAB)
# National Reference laboratory, Block E, Sector
# 18, ROHINI
# DELHI 110085LPL-NATIONAL REFERENCE LAB
# National Reference laboratory, Block E,
# Sector 18, Rohini, New Delhi -110085
# Test Report
# Test Name Results Units Bio. Ref. Interval
# LIVER & KIDNEY PANEL, SERUM
# 0.90 Creatinine
# (Modified Jaffe,Kinetic) 0.70 - 1.30 mg/dL
# 118 GFR Estimated
# (CKD EPI Equation 2021) >59 mL/min/1.73m2
# G1 GFR Category
# (KDIGO Guideline 2012)
# 20.00 Urea
# (Urease UV) 13.00 - 43.00 mg/dL
# 9.34 Urea Nitrogen  Blood
# (Calculated) 6.00 - 20.00 mg/dL
# 10 BUN/Creatinine Ratio
# (Calculated)
# 5.00 Uric Acid
# (Uricase) 3.50 - 7.20 mg/dL
# 11.0 AST (SGOT)
# (IFCC without P5P) 15.00 - 40.00 U/L
# 21.0 ALT (SGPT)
# (IFCC without P5P) 10.00 - 49.00 U/L
# 11.0 GGTP
# (IFCC) 0 - 73 U/L
# 150.00 Alkaline Phosphatase (ALP)
# (IFCC-AMP) 30.00 - 120.00 U/L
# 0.20 Bilirubin  Total
# (Oxidation) 0.30 - 1.20 mg/dL
# 0.10 Bilirubin  Direct
# (Oxidation) <0.3 mg/dL
# 0.10 Bilirubin  Indirect
# (Calculated) <1.10 mg/dL
# 7.00 Total Protein
# (Biuret) 5.70 - 8.20 g/dL
# 4.00 Albumin
# (BCG) 3.20 - 4.80 g/dL
# 1.33 A : G Ratio
# (Calculated) 0.90 - 2.00
# 3.00 Globulin(Calculated)  2.0 - 3.5 gm/dL
# 8.00 Calcium, Total
# (Arsenazo III) 8.70 - 10.40 mg/dL
# *439854467*
# .
# Page 3 of 10
#
# # Agent: Blood Test Analyst
# ## Task: You have to analyze the blood test report from "Report Status    Male30 Years:
# :
# :
# :Age
# Gender
# Reported
# P14/5/2023  11:03:00AMU439854467   DUMMY:
# :
# :
# :
# :Name
# Lab No.
# Ref By
# Collected
# A/c Status 16/5/2023  1:36:25PM
# Final
# Collected at            : Processed at             : LPL-ROHINI (NATIONAL REFERENCE LAB)
# National Reference laboratory, Block E, Sector
# 18, ROHINI
# DELHI 110085LPL-NATIONAL REFERENCE LAB
# National Reference laboratory, Block E,
# Sector 18, Rohini, New Delhi -110085
# Test Report
# Test Name Results Units Bio. Ref. Interval
# SwasthFit Super 4
# COMPLETE BLOOD COUNT;CBC
# Hemoglobin
# (Photometry) 13.00 - 17.00 g/dL 15.00
# Packed Cell Volume (PCV)
# (Calculated) 40.00 - 50.00 % 45.00
# RBC Count
# (Electrical Impedence) 4.50 - 5.50 mill/mm3 4.50
# MCV
# (Electrical Impedence) 83.00 - 101.00 fL 90.00
# MCH
# (Calculated) 27.00 - 32.00 pg 32.00
# MCHC
# (Calculated) 31.50 - 34.50 g/dL 33.00
# Red Cell Distribution Width (RDW)
# (Electrical Impedence) 11.60 - 14.00 % 14.00
# Total Leukocyte Count  (TLC)
# (Electrical Impedence) 4.00 - 10.00 thou/mm3 8.00
# Differential Leucocyte Count (DLC)
# (VCS Technology)
#  40.00 - 80.00 Segmented Neutrophils % 60.00
#  20.00 - 40.00 Lymphocytes % 30.00
#  2.00 - 10.00 Monocytes % 5.00
#  1.00 - 6.00 Eosinophils % 5.00
#  <2.00 Basophils % 0.00
# Absolute Leucocyte Count
# (Calculated)
#  2.00 - 7.00 Neutrophils thou/mm3 4.80
#  1.00 - 3.00 Lymphocytes thou/mm3 2.40
#  0.20 - 1.00 Monocytes thou/mm3 0.40
#  0.02 - 0.50 Eosinophils thou/mm3 0.40
#  0.02 - 0.10 Basophils thou/mm3 0.00
# Platelet Count
# (Electrical impedence) 150.00 - 410.00 thou/mm3 200
# Mean Platelet Volume
# (Electrical Impedence) 6.5 - 12.0 fL 10.0
# *439854467*
# .
# Page 1 of 10
# Report Status    Male30 Years:
# :
# :
# :Age
# Gender
# Reported
# P14/5/2023  11:03:00AMU439854467   DUMMY:
# :
# :
# :
# :Name
# Lab No.
# Ref By
# Collected
# A/c Status 16/5/2023  1:36:25PM
# Final
# Collected at            : Processed at             : LPL-ROHINI (NATIONAL REFERENCE LAB)
# National Reference laboratory, Block E, Sector
# 18, ROHINI
# DELHI 110085LPL-NATIONAL REFERENCE LAB
# National Reference laboratory, Block E,
# Sector 18, Rohini, New Delhi -110085
# Test Report
# Test Name Results Units Bio. Ref. Interval
# LIVER & KIDNEY PANEL, SERUM
# 0.90 Creatinine
# (Modified Jaffe,Kinetic) 0.70 - 1.30 mg/dL
# 118 GFR Estimated
# (CKD EPI Equation 2021) >59 mL/min/1.73m2
# G1 GFR Category
# (KDIGO Guideline 2012)
# 20.00 Urea
# (Urease UV) 13.00 - 43.00 mg/dL
# 9.34 Urea Nitrogen  Blood
# (Calculated) 6.00 - 20.00 mg/dL
# 10 BUN/Creatinine Ratio
# (Calculated)
# 5.00 Uric Acid
# (Uricase) 3.50 - 7.20 mg/dL
# 11.0 AST (SGOT)
# (IFCC without P5P) 15.00 - 40.00 U/L
# 21.0 ALT (SGPT)
# (IFCC without P5P) 10.00 - 49.00 U/L
# 11.0 GGTP
# (IFCC) 0 - 73 U/L
# 150.00 Alkaline Phosphatase (ALP)
# (IFCC-AMP) 30.00 - 120.00 U/L
# 0.20 Bilirubin  Total
# (Oxidation) 0.30 - 1.20 mg/dL
# 0.10 Bilirubin  Direct
# (Oxidation) <0.3 mg/dL
# 0.10 Bilirubin  Indirect
# (Calculated) <1.10 mg/dL
# 7.00 Total Protein
# (Biuret) 5.70 - 8.20 g/dL
# 4.00 Albumin
# (BCG) 3.20 - 4.80 g/dL
# 1.33 A : G Ratio
# (Calculated) 0.90 - 2.00
# 3.00 Globulin(Calculated)  2.0 - 3.5 gm/dL
# 8.00 Calcium, Total
# (Arsenazo III) 8.70 - 10.40 mg/dL
# *439854467*
# .
# Page 3 of 10
# " blood report
#
#
# # Agent: Blood Test Analyst
# ## Final Answer:
# The blood test report for a 30-year-old male shows the following results:
#
# ### Complete Blood Count (CBC)
# - **Hemoglobin (Photometry)**: 15.00 g/dL (Reference range: 13.00 - 17.00 g/dL)
# - **Packed Cell Volume (PCV) (Calculated)**: 45.00% (Reference range: 40.00 - 50.00%)
# - **RBC Count (Electrical Impedance)**: 4.50 mill/mm3 (Reference range: 4.50 - 5.50 mill/mm3)
# - **MCV (Electrical Impedance)**: 90.00 fL (Reference range: 83.00 - 101.00 fL)
# - **MCH (Calculated)**: 32.00 pg (Reference range: 27.00 - 32.00 pg)
# - **MCHC (Calculated)**: 33.00 g/dL (Reference range: 31.50 - 34.50 g/dL)
# - **Red Cell Distribution Width (RDW) (Electrical Impedance)**: 14.00% (Reference range: 11.60 - 14.00%)
# - **Total Leukocyte Count (TLC) (Electrical Impedance)**: 8.00 thou/mm3 (Reference range: 4.00 - 10.00 thou/mm3)
#
# ### Differential Leukocyte Count (DLC)
# - **Segmented Neutrophils**: 60.00% (Reference range: 40.00 - 80.00%)
# - **Lymphocytes**: 30.00% (Reference range: 20.00 - 40.00%)
# - **Monocytes**: 5.00% (Reference range: 2.00 - 10.00%)
# - **Eosinophils**: 5.00% (Reference range: 1.00 - 6.00%)
# - **Basophils**: 0.00% (Reference range: <2.00%)
#
# ### Absolute Leukocyte Count
# - **Neutrophils**: 4.80 thou/mm3 (Reference range: 2.00 - 7.00 thou/mm3)
# - **Lymphocytes**: 2.40 thou/mm3 (Reference range: 1.00 - 3.00 thou/mm3)
# - **Monocytes**: 0.40 thou/mm3 (Reference range: 0.20 - 1.00 thou/mm3)
# - **Eosinophils**: 0.40 thou/mm3 (Reference range: 0.02 - 0.50 thou/mm3)
# - **Basophils**: 0.00 thou/mm3 (Reference range: 0.02 - 0.10 thou/mm3)
#
# ### Platelet Count
# - **Platelet Count (Electrical Impedance)**: 200 thou/mm3 (Reference range: 150.00 - 410.00 thou/mm3)
# - **Mean Platelet Volume (Electrical Impedance)**: 10.0 fL (Reference range: 6.5 - 12.0 fL)
#
# ### Liver & Kidney Panel, Serum
# - **Creatinine (Modified Jaffe, Kinetic)**: 0.90 mg/dL (Reference range: 0.70 - 1.30 mg/dL)
# - **GFR Estimated (CKD EPI Equation 2021)**: 118 mL/min/1.73m2 (Reference range: >59 mL/min/1.73m2); G1 GFR Category (KDIGO Guideline 2012)
# - **Urea (Urease UV)**: 20.00 mg/dL (Reference range: 13.00 - 43.00 mg/dL)
# - **Urea Nitrogen Blood (Calculated)**: 9.34 mg/dL (Reference range: 6.00 - 20.00 mg/dL)
# - **BUN/Creatinine Ratio (Calculated)**: 10
# - **Uric Acid (Uricase)**: 5.00 mg/dL (Reference range: 3.50 - 7.20 mg/dL)
# - **AST (SGOT) (IFCC without P5P)**: 11.0 U/L (Reference range: 15.00 - 40.00 U/L)
# - **ALT (SGPT) (IFCC without P5P)**: 21.0 U/L (Reference range: 10.00 - 49.00 U/L)
# - **GGTP (IFCC)**: 11.0 U/L (Reference range: 0 - 73 U/L)
# - **Alkaline Phosphatase (ALP) (IFCC-AMP)**: 150.00 U/L (Reference range: 30.00 - 120.00 U/L)
# - **Bilirubin Total (Oxidation)**: 0.20 mg/dL (Reference range: 0.30 - 1.20 mg/dL)
# - **Bilirubin Direct (Oxidation)**: 0.10 mg/dL (Reference range: <0.3 mg/dL)
# - **Bilirubin Indirect (Calculated)**: 0.10 mg/dL (Reference range: <1.10 mg/dL)
# - **Total Protein (Biuret)**: 7.00 g/dL (Reference range: 5.70 - 8.20 g/dL)
# - **Albumin (BCG)**: 4.00 g/dL (Reference range: 3.20 - 4.80 g/dL)
# - **A : G Ratio (Calculated)**: 1.33 (Reference range: 0.90 - 2.00)
# - **Globulin (Calculated)**: 3.00 gm/dL (Reference range: 2.0 - 3.5 gm/dL)
# - **Calcium, Total (Arsenazo III)**: 8.00 mg/dL (Reference range: 8.70 - 10.40 mg/dL)
#
# The blood test results mostly fall within the biological reference intervals, indicating normal functioning. Notably, the Alkaline Phosphatase (ALP) is slightly elevated. Consultation with a healthcare provider is recommended for a comprehensive interpretation of these results.
# # Agent: Article Researcher
# ## Task: Search for health articles based on the blood test analysis.
#
#
# # Agent: Article Researcher
# ## Thought: Given the above blood test results and the need to find relevant health articles, focusing on the slight elevation in Alkaline Phosphatase (ALP) and generally good CBC, liver, and kidney panels will be essential. I'll start by searching for articles discussing elevated ALP levels and general interpretations of normal blood test results.
# ## Using tool: Search the internet
# ## Tool Input:
# {
#   "search_query": "elevated Alkaline Phosphatase (ALP) causes and implications health articles"
# }
# ## Tool Output:
#
# Search results: Title: Alkaline Phosphatase - StatPearls - NCBI Bookshelf
# Link: https://www.ncbi.nlm.nih.gov/books/NBK459201/
# Snippet: The principal clinical significance of measuring serum ALP levels is diagnosing cholestatic liver disease ... cause of the elevated serum ALP.[57].
# ---
# Title: Alkaline Phosphatase (ALP): What It Is, Causes & Treatment
# Link: https://my.clevelandclinic.org/health/diagnostics/22029-alkaline-phosphatase-alp
# Snippet: High levels of ALP may indicate liver disease or certain bone disorders, but an ALP test alone cannot diagnose a condition.
# ---
# Title: Elevated Levels of Serum Alkaline Phosphatase are Associated with ...
# Link: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10322736/
# Snippet: Conclusions: Higher ALP levels, even within the normal range, were significantly associated with increased risks of CVD, in a dose-dependent manner. These ...
# ---
# Title: Alkaline phosphatase (ALP) level test: High and low levels
# Link: https://www.medicalnewstoday.com/articles/321984
# Snippet: Having high or low ALP levels can indicate an underlying condition. Unusual ALP levels may be a sign of liver problems, a bone disorder, some types of cancer, ...
# ---
# Title: Elevated Alkaline Phosphatase - an overview | ScienceDirect Topics
# Link: https://www.sciencedirect.com/topics/medicine-and-dentistry/elevated-alkaline-phosphatase
# Snippet: ALP levels as high as three times normal occur in many liver diseases. More pronounced increases suggest infiltrative processes or biliary obstruction, which ...
# ---
# Title: Alkaline Phosphatase (ALP) Test - Testing.com
# Link: https://www.testing.com/tests/alkaline-phosphatase-alp/
# Snippet: Abnormal levels of ALP can be caused by liver or bone conditions and other types of health problems. ALP can be tested alone, but because many ...
# ---
# Title: An Alkaline Phosphatase (ALP) Test: Levels and More - Healthline
# Link: https://www.healthline.com/health/alp
# Snippet: Higher-than-normal levels of ALP in your blood may indicate a health concern with your liver or gallbladder. This could include a blockage in your bile ducts, ...
# ---
# Title: Causes of High Bone Alkaline Phosphatase - Taylor & Francis Online
# Link: https://www.tandfonline.com/doi/abs/10.1080/13102818.2007.10817444
# Snippet: Causes of high bone ALP include bone growth, healing fracture, acromegaly, osteogenic sarcoma, or bone metastases, leukemia, myelofibrosis, and rarely myeloma.
# ---
# Title: Elevated Alkaline Phosphatase - an overview | ScienceDirect Topics
# Link: https://www.sciencedirect.com/topics/biochemistry-genetics-and-molecular-biology/elevated-alkaline-phosphatase
# Snippet: The serum alkaline phosphatase is increased by drugs that cause cholestatic liver disease; elevation was also reportedly caused by cimetidine,14 frusemide,15 ...
# ---
# Title: THU471 Resolution Of Elevated Alkaline Phosphatase After Joint ...
# Link: https://academic.oup.com/jes/article/7/Supplement_1/bvad114.432/7290916
# Snippet: Conditions of high turnover such as healing fractures, hyperparathyroidism, Pagets' disease of the bone, also lead to ALP elevation (1).
# ---
#
#
#
# # Agent: Article Researcher
# ## Thought: Thought: To ensure a thorough response, I'll also look for articles about normal blood test results to provide a complete picture.
# ## Using tool: Search the internet
# ## Tool Input:
# {
#   "search_query": "understanding normal blood test results health articles"
# }
# ## Tool Output:
#
# Search results: Title: Blood Tests | NHLBI, NIH
# Link: https://www.nhlbi.nih.gov/health/blood-tests
# Snippet: The table below shows some normal adult ranges for different parts of the CBC test. Some of the normal ranges differ between men and women.
# ---
# Title: How to Read Your Blood Test Results | Ada Health
# Link: https://ada.com/blood-test-results/
# Snippet: Results outside of the normal range can be a sign of anemia or chronic fatigue syndrome, among other medical conditions.
# ---
# Title: Blood Tests: Types, Results & How They Work - Cleveland Clinic
# Link: https://my.clevelandclinic.org/health/diagnostics/24508-blood-tests
# Snippet: A blood test is one of the most common tests healthcare providers use to monitor your overall health or help diagnose medical conditions.
# ---
# Title: How to Understand Your Lab Results: MedlinePlus Medical Test
# Link: https://medlineplus.gov/lab-tests/how-to-understand-your-lab-results/
# Snippet: Reference ranges are a general guide to "normal." If your test result is higher or lower than the range that applies to you, it may be a sign ...
# ---
# Title: Reference Ranges and What They Mean - Testing.com
# Link: https://www.testing.com/articles/laboratory-test-reference-ranges/
# Snippet: A reference range is a set of values with an upper and lower limit of a lab test. Reference ranges help to interpret your results.
# ---
# Title: What do your blood test results mean? A toxicologist explains the ...
# Link: https://theconversation.com/what-do-your-blood-test-results-mean-a-toxicologist-explains-the-basics-of-how-to-interpret-them-216341
# Snippet: Understanding what common blood tests are intended to measure can help you better interpret the results. If you have results from a recent blood ...
# ---
# Title: Lab Values, Normal Adult - Medscape Reference
# Link: https://emedicine.medscape.com/article/2172316-overview
# Snippet: Hemoglobin: Female: 12–16 g/dL; male: 14–18 g/dL. Hematocrit Female: 37%–47%; male: 42%–50%.
# ---
# Title: Understanding Your Lab Test Results | American Cancer Society
# Link: https://www.cancer.org/cancer/diagnosis-staging/tests/understanding-your-lab-test-results.html
# Snippet: Different labs can have different normal ranges for blood tests. By getting a copy of your test results, you can see what the normal ranges are ...
# ---
# Title: Blood tests in primary care: A qualitative study of communication ...
# Link: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9615068/
# Snippet: The aim of this study was to explore communication and decision‐making around diagnostic blood tests in primary care.
# ---
# Title: Decoding Blood Tests: A GoodRx Guide to Lab Results
# Link: https://www.goodrx.com/health-topic/diagnostics/blood-test-guide
# Snippet: We're here to walk you through the most common lab tests and what they mean. We'll also explain which values are considered normal.
# ---
#
#
#
# # Agent: Article Researcher
# ## Final Answer:
# Here is a list of relevant health articles based on the blood test analysis provided:
#
# 1. **Alkaline Phosphatase - StatPearls - NCBI Bookshelf**
#    - [Read Article](https://www.ncbi.nlm.nih.gov/books/NBK459201/)
#    - This article discusses the clinical significance of measuring serum ALP levels in diagnosing cholestatic liver disease and potential causes of elevated serum ALP.
#
# 2. **Alkaline Phosphatase (ALP): What It Is, Causes & Treatment**
#    - [Read Article](https://my.clevelandclinic.org/health/diagnostics/22029-alkaline-phosphatase-alp)
#    - This article explains high ALP levels, which may indicate liver disease or certain bone disorders, emphasizing that an ALP test alone cannot diagnose a condition.
#
# 3. **Elevated Levels of Serum Alkaline Phosphatase are Associated with Increased Risks of CVD**
#    - [Read Article](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10322736/)
#    - This study finds that higher ALP levels within the normal range are significantly associated with increased cardiovascular disease risks.
#
# 4. **Alkaline Phosphatase (ALP) level test: High and low levels**
#    - [Read Article](https://www.medicalnewstoday.com/articles/321984)
#    - This article elaborates on how high or low ALP levels can indicate underlying conditions, including liver problems and bone disorders.
#
# 5. **Elevated Alkaline Phosphatase - an overview | ScienceDirect Topics**
#    - [Read Article](https://www.sciencedirect.com/topics/medicine-and-dentistry/elevated-alkaline-phosphatase)
#    - This overview examines the implications of elevated ALP levels, suggesting that significantly high levels may indicate liver disease or biliary obstruction.
#
# 6. **Alkaline Phosphatase (ALP) Test - Testing.com**
#    - [Read Article](https://www.testing.com/tests/alkaline-phosphatase-alp/)
#    - This article details how abnormal ALP levels can be indicative of liver or bone conditions and other types of health problems.
#
# 7. **An Alkaline Phosphatase (ALP) Test: Levels and More - Healthline**
#    - [Read Article](https://www.healthline.com/health/alp)
#    - This article discusses higher-than-normal ALP levels and their possible indications, such as liver or gallbladder health concerns.
#
# 8. **Causes of High Bone Alkaline Phosphatase - Taylor & Francis Online**
#    - [Read Article](https://www.tandfonline.com/doi/abs/10.1080/13102818.2007.10817444)
#    - This study explains high bone ALP causes, including bone growth, healing fractures, and certain bone disorders.
#
# 9. **Blood Tests | NHLBI, NIH**
#    - [Read Article](https://www.nhlbi.nih.gov/health/blood-tests)
#    - This article provides a comprehensive overview of blood tests, including normal adult ranges for different parts of the CBC test.
#
# 10. **How to Read Your Blood Test Results | Ada Health**
#     - [Read Article](https://ada.com/blood-test-results/)
#     - This guide helps in understanding blood test results, indicating potential conditions if results fall outside normal ranges.
#
# 11. **Blood Tests: Types, Results & How They Work - Cleveland Clinic**
#     - [Read Article](https://my.clevelandclinic.org/health/diagnostics/24508-blood-tests)
#     - This article explains different types of blood tests used to monitor overall health or diagnose medical conditions.
#
# 12. **How to Understand Your Lab Results: MedlinePlus Medical Test**
#     - [Read Article](https://medlineplus.gov/lab-tests/how-to-understand-your-lab-results/)
#     - This guide explains reference ranges and what it means if your test result is higher or lower than these ranges.
#
# 13. **Reference Ranges and What They Mean - Testing.com**
#     - [Read Article](https://www.testing.com/articles/laboratory-test-reference-ranges/)
#     - This article defines reference ranges and helps in interpreting laboratory test results.
#
# 14. **What do your blood test results mean? A toxicologist explains the basics**
#     - [Read Article](https://theconversation.com/what-do-your-blood-test-results-mean-a-toxicologist-explains-the-basics-of-how-to-interpret-them-216341)
#     - This guide helps interpret common blood tests and what different results might signify.
#
# 15. **Lab Values, Normal Adult - Medscape Reference**
#     - [Read Article](https://emedicine.medscape.com/article/2172316-overview)
#     - This reference provides normal adult lab values for various blood components.
#
# 16. **Understanding Your Lab Test Results | American Cancer Society**
#     - [Read Article](https://www.cancer.org/cancer/diagnosis-staging/tests/understanding-your-lab-test-results.html)
#     - This article explains the significance of lab test results and what different values might indicate.
#
# 17. **Decoding Blood Tests: A GoodRx Guide to Lab Results**
#     - [Read Article](https://www.goodrx.com/health-topic/diagnostics/blood-test-guide)
#     - This guide walks through the most common lab tests and explains what different values mean, identifying which are considered normal.
# # Agent: Health Advisor
# ## Task: Provide health recommendations based on the articles found.
#
#
# # Agent: Health Advisor
# ## Final Answer:
# Here are some comprehensive health recommendations based on the articles found.
#
# 1. **Understanding Alkaline Phosphatase Levels:**
#     - **Alkaline Phosphatase - StatPearls - NCBI Bookshelf**
#       - [Read Article](https://www.ncbi.nlm.nih.gov/books/NBK459201/)
#       - This article discusses the clinical significance of measuring serum ALP levels in diagnosing cholestatic liver disease and potential causes of elevated serum ALP.
#
#     - **Alkaline Phosphatase (ALP): What It Is, Causes & Treatment**
#       - [Read Article](https://my.clevelandclinic.org/health/diagnostics/22029-alkaline-phosphatase-alp)
#       - This article explains high ALP levels, which may indicate liver disease or certain bone disorders, emphasizing that an ALP test alone cannot diagnose a condition.
#
#     - **Elevated Levels of Serum Alkaline Phosphatase are Associated with Increased Risks of CVD**
#       - [Read Article](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10322736/)
#       - This study finds that higher ALP levels within the normal range are significantly associated with increased cardiovascular disease risks.
#
#     - **Alkaline Phosphatase (ALP) level test: High and low levels**
#       - [Read Article](https://www.medicalnewstoday.com/articles/321984)
#       - This article elaborates on how high or low ALP levels can indicate underlying conditions, including liver problems and bone disorders.
#
#     - **Elevated Alkaline Phosphatase - an overview | ScienceDirect Topics**
#       - [Read Article](https://www.sciencedirect.com/topics/medicine-and-dentistry/elevated-alkaline-phosphatase)
#       - This overview examines the implications of elevated ALP levels, suggesting that significantly high levels may indicate liver disease or biliary obstruction.
#
#     - **Alkaline Phosphatase (ALP) Test - Testing.com**
#       - [Read Article](https://www.testing.com/tests/alkaline-phosphatase-alp/)
#       - This article details how abnormal ALP levels can be indicative of liver or bone conditions and other types of health problems.
#
#     - **An Alkaline Phosphatase (ALP) Test: Levels and More - Healthline**
#       - [Read Article](https://www.healthline.com/health/alp)
#       - This article discusses higher-than-normal ALP levels and their possible indications, such as liver or gallbladder health concerns.
#
#     - **Causes of High Bone Alkaline Phosphatase - Taylor & Francis Online**
#       - [Read Article](https://www.tandfonline.com/doi/abs/10.1080/13102818.2007.10817444)
#       - This study explains high bone ALP causes, including bone growth, healing fractures, and certain bone disorders.
#
# 2. **Interpreting Blood Test Results:**
#     - **Blood Tests | NHLBI, NIH**
#       - [Read Article](https://www.nhlbi.nih.gov/health/blood-tests)
#       - This article provides a comprehensive overview of blood tests, including normal adult ranges for different parts of the CBC test.
#
#     - **How to Read Your Blood Test Results | Ada Health**
#       - [Read Article](https://ada.com/blood-test-results/)
#       - This guide helps in understanding blood test results, indicating potential conditions if results fall outside normal ranges.
#
#     - **Blood Tests: Types, Results & How They Work - Cleveland Clinic**
#       - [Read Article](https://my.clevelandclinic.org/health/diagnostics/24508-blood-tests)
#       - This article explains different types of blood tests used to monitor overall health or diagnose medical conditions.
#
#     - **How to Understand Your Lab Results: MedlinePlus Medical Test**
#       - [Read Article](https://medlineplus.gov/lab-tests/how-to-understand-your-lab-results/)
#       - This guide explains reference ranges and what it means if your test result is higher or lower than these ranges.
#
#     - **Reference Ranges and What They Mean - Testing.com**
#       - [Read Article](https://www.testing.com/articles/laboratory-test-reference-ranges/)
#       - This article defines reference ranges and helps in interpreting laboratory test results.
#
#     - **What do your blood test results mean? A toxicologist explains the basics**
#       - [Read Article](https://theconversation.com/what-do-your-blood-test-results-mean-a-toxicologist-explains-the-basics-of-how-to-interpret-them-216341)
#       - This guide helps interpret common blood tests and what different results might signify.
#
#     - **Lab Values, Normal Adult - Medscape Reference**
#       - [Read Article](https://emedicine.medscape.com/article/2172316-overview)
#       - This reference provides normal adult lab values for various blood components.
#
#     - **Understanding Your Lab Test Results | American Cancer Society**
#       - [Read Article](https://www.cancer.org/cancer/diagnosis-staging/tests/understanding-your-lab-test-results.html)
#       - This article explains the significance of lab test results and what different values might indicate.
#
#     - **Decoding Blood Tests: A GoodRx Guide to Lab Results**
#       - [Read Article](https://www.goodrx.com/health-topic/diagnostics/blood-test-guide)
#       - This guide walks through the most common lab tests and explains what different values mean, identifying which are considered normal.
#
# These articles will provide a broad understanding of ALP and other blood test results, helping individuals interpret their health data accurately and effectively.
# CrewOutput(raw='Here are some comprehensive health recommendations based on the articles found. \n\n1. **Understanding Alkaline Phosphatase Levels:**\n    - **Alkaline Phosphatase - StatPearls - NCBI Bookshelf**\n      - [Read Article](https://www.ncbi.nlm.nih.gov/books/NBK459201/)\n      - This article discusses the clinical significance of measuring serum ALP levels in diagnosing cholestatic liver disease and potential causes of elevated serum ALP.\n    \n    - **Alkaline Phosphatase (ALP): What It Is, Causes & Treatment**\n      - [Read Article](https://my.clevelandclinic.org/health/diagnostics/22029-alkaline-phosphatase-alp)\n      - This article explains high ALP levels, which may indicate liver disease or certain bone disorders, emphasizing that an ALP test alone cannot diagnose a condition.\n    \n    - **Elevated Levels of Serum Alkaline Phosphatase are Associated with Increased Risks of CVD**\n      - [Read Article](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10322736/)\n      - This study finds that higher ALP levels within the normal range are significantly associated with increased cardiovascular disease risks.\n    \n    - **Alkaline Phosphatase (ALP) level test: High and low levels**\n      - [Read Article](https://www.medicalnewstoday.com/articles/321984)\n      - This article elaborates on how high or low ALP levels can indicate underlying conditions, including liver problems and bone disorders.\n    \n    - **Elevated Alkaline Phosphatase - an overview | ScienceDirect Topics**\n      - [Read Article](https://www.sciencedirect.com/topics/medicine-and-dentistry/elevated-alkaline-phosphatase)\n      - This overview examines the implications of elevated ALP levels, suggesting that significantly high levels may indicate liver disease or biliary obstruction.\n    \n    - **Alkaline Phosphatase (ALP) Test - Testing.com**\n      - [Read Article](https://www.testing.com/tests/alkaline-phosphatase-alp/)\n      - This article details how abnormal ALP levels can be indicative of liver or bone conditions and other types of health problems.\n    \n    - **An Alkaline Phosphatase (ALP) Test: Levels and More - Healthline**\n      - [Read Article](https://www.healthline.com/health/alp)\n      - This article discusses higher-than-normal ALP levels and their possible indications, such as liver or gallbladder health concerns.\n    \n    - **Causes of High Bone Alkaline Phosphatase - Taylor & Francis Online**\n      - [Read Article](https://www.tandfonline.com/doi/abs/10.1080/13102818.2007.10817444)\n      - This study explains high bone ALP causes, including bone growth, healing fractures, and certain bone disorders.\n\n2. **Interpreting Blood Test Results:**\n    - **Blood Tests | NHLBI, NIH**\n      - [Read Article](https://www.nhlbi.nih.gov/health/blood-tests)\n      - This article provides a comprehensive overview of blood tests, including normal adult ranges for different parts of the CBC test.\n    \n    - **How to Read Your Blood Test Results | Ada Health**\n      - [Read Article](https://ada.com/blood-test-results/)\n      - This guide helps in understanding blood test results, indicating potential conditions if results fall outside normal ranges.\n    \n    - **Blood Tests: Types, Results & How They Work - Cleveland Clinic**\n      - [Read Article](https://my.clevelandclinic.org/health/diagnostics/24508-blood-tests)\n      - This article explains different types of blood tests used to monitor overall health or diagnose medical conditions.\n    \n    - **How to Understand Your Lab Results: MedlinePlus Medical Test**\n      - [Read Article](https://medlineplus.gov/lab-tests/how-to-understand-your-lab-results/)\n      - This guide explains reference ranges and what it means if your test result is higher or lower than these ranges.\n    \n    - **Reference Ranges and What They Mean - Testing.com**\n      - [Read Article](https://www.testing.com/articles/laboratory-test-reference-ranges/)\n      - This article defines refere ...
